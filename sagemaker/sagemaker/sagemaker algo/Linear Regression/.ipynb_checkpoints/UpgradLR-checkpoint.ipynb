# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt


from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()

# %%
dfTrain = pd.read_csv('train.csv', parse_dates=['datetime'],index_col=0)

# %%
dfTrain.columns
# Out:
# Index(['season', 'holiday', 'workingday', 'weather', 'temp', 'atemp',
#        'humidity', 'windspeed', 'count'],
#       dtype='object')

# %%
len(dfTrain.columns)
# Out:
# 9

# %%
dfTrain.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 10886 entries, 2011-01-01 00:00:00 to 2012-12-19 23:00:00
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   season      10886 non-null  int64
#  1   holiday     10886 non-null  int64
#  2   workingday  10886 non-null  int64
#  3   weather     10886 non-null  int64
#  4   temp        10886 non-null  float64
#  5   atemp       10886 non-null  float64
#  6   humidity    10886 non-null  int64
#  7   windspeed   10886 non-null  float64
#  8   count       10886 non-null  int64
# dtypes: float64(3), int64(6)
# memory usage: 850.5 KB

# %%
dfTrain.describe()
# Out:
#              season       holiday    workingday       weather         temp  \
# count  10886.000000  10886.000000  10886.000000  10886.000000  10886.00000
# mean       2.506614      0.028569      0.680875      1.418427     20.23086
# std        1.116174      0.166599      0.466159      0.633839      7.79159
# min        1.000000      0.000000      0.000000      1.000000      0.82000
# 25%        2.000000      0.000000      0.000000      1.000000     13.94000
# 50%        3.000000      0.000000      1.000000      1.000000     20.50000
# 75%        4.000000      0.000000      1.000000      2.000000     26.24000
# max        4.000000      1.000000      1.000000      4.000000     41.00000
#
#               atemp      humidity     windspeed         count
# count  10886.000000  10886.000000  10886.000000  10886.000000
# mean      23.655084     61.886460     12.799395    191.574132
# std        8.474601     19.245033      8.164537    181.144454
# ...

# %%
columnsRequired=['count','season', 'holiday', 'workingday', 'weather', 'temp', 'atemp',
       'humidity', 'windspeed']

# %%
dfTrain=dfTrain[columnsRequired]

# %%
len(dfTrain.columns)
# Out:
# 9

# %%
dfTrain.head()
# Out:
#                      count  season  holiday  workingday  weather  temp  \
# datetime
# 2011-01-01 00:00:00     16       1        0           0        1  9.84
# 2011-01-01 01:00:00     40       1        0           0        1  9.02
# 2011-01-01 02:00:00     32       1        0           0        1  9.02
# 2011-01-01 03:00:00     13       1        0           0        1  9.84
# 2011-01-01 04:00:00      1       1        0           0        1  9.84
#
#                       atemp  humidity  windspeed
# datetime
# 2011-01-01 00:00:00  14.395        81        0.0
# 2011-01-01 01:00:00  13.635        80        0.0
# 2011-01-01 02:00:00  13.635        80        0.0
# 2011-01-01 03:00:00  14.395        75        0.0
# 2011-01-01 04:00:00  14.395        75        0.0

# %%
dfTrain['year'] = dfTrain.index.year

# %%
dfTrain['year'] = dfTrain.index.year
dfTrain['month'] = dfTrain.index.month
dfTrain['day'] = dfTrain.index.day
dfTrain['dayofweek'] = dfTrain.index.dayofweek
dfTrain['hour'] = dfTrain.index.hour

# %%
dfTrain.head()
# Out:
#                      count  season  holiday  workingday  weather  temp  \
# datetime
# 2011-01-01 00:00:00     16       1        0           0        1  9.84
# 2011-01-01 01:00:00     40       1        0           0        1  9.02
# 2011-01-01 02:00:00     32       1        0           0        1  9.02
# 2011-01-01 03:00:00     13       1        0           0        1  9.84
# 2011-01-01 04:00:00      1       1        0           0        1  9.84
#
#                       atemp  humidity  windspeed  year  month  day  dayofweek  \
# datetime
# 2011-01-01 00:00:00  14.395        81        0.0  2011      1    1          5
# 2011-01-01 01:00:00  13.635        80        0.0  2011      1    1          5
# 2011-01-01 02:00:00  13.635        80        0.0  2011      1    1          5
# 2011-01-01 03:00:00  14.395        75        0.0  2011      1    1          5
# 2011-01-01 04:00:00  14.395        75        0.0  2011      1    1          5
#
#                      hour
# datetime
# ...

# %%
dfTrain.columns
# Out:
# Index(['count', 'season', 'holiday', 'workingday', 'weather', 'temp', 'atemp',
#        'humidity', 'windspeed', 'year', 'month', 'day', 'dayofweek', 'hour'],
#       dtype='object')

# %%
np.log1p(13)
# Out:
# 2.639057329615259

# %%
np.expm1(2.639057329615259)
# Out:
# 13.000000000000004

# %%
dfTrain["count"] = dfTrain["count"].map(np.log1p)

# %%
dfTrain.head()
# Out:
#                         count  season  holiday  workingday  weather  temp  \
# datetime
# 2011-01-01 00:00:00  2.833213       1        0           0        1  9.84
# 2011-01-01 01:00:00  3.713572       1        0           0        1  9.02
# 2011-01-01 02:00:00  3.496508       1        0           0        1  9.02
# 2011-01-01 03:00:00  2.639057       1        0           0        1  9.84
# 2011-01-01 04:00:00  0.693147       1        0           0        1  9.84
#
#                       atemp  humidity  windspeed  year  month  day  dayofweek  \
# datetime
# 2011-01-01 00:00:00  14.395        81        0.0  2011      1    1          5
# 2011-01-01 01:00:00  13.635        80        0.0  2011      1    1          5
# 2011-01-01 02:00:00  13.635        80        0.0  2011      1    1          5
# 2011-01-01 03:00:00  14.395        75        0.0  2011      1    1          5
# 2011-01-01 04:00:00  14.395        75        0.0  2011      1    1          5
#
#                      hour
# ...

# %%
dfTrain.describe()
# Out:
#               count        season       holiday    workingday       weather  \
# count  10886.000000  10886.000000  10886.000000  10886.000000  10886.000000
# mean       4.591364      2.506614      0.028569      0.680875      1.418427
# std        1.419454      1.116174      0.166599      0.466159      0.633839
# min        0.693147      1.000000      0.000000      0.000000      1.000000
# 25%        3.761200      2.000000      0.000000      0.000000      1.000000
# 50%        4.983607      3.000000      0.000000      1.000000      1.000000
# 75%        5.652489      4.000000      0.000000      1.000000      2.000000
# max        6.885510      4.000000      1.000000      1.000000      4.000000
#
#               temp         atemp      humidity     windspeed          year  \
# count  10886.00000  10886.000000  10886.000000  10886.000000  10886.000000
# mean      20.23086     23.655084     61.886460     12.799395   2011.501929
# ...

# %%
l = list(dfTrain.index)

# %%
l
# Out:
# [Timestamp('2011-01-01 00:00:00'),
#  Timestamp('2011-01-01 01:00:00'),
#  Timestamp('2011-01-01 02:00:00'),
#  Timestamp('2011-01-01 03:00:00'),
#  Timestamp('2011-01-01 04:00:00'),
#  Timestamp('2011-01-01 05:00:00'),
#  Timestamp('2011-01-01 06:00:00'),
#  Timestamp('2011-01-01 07:00:00'),
#  Timestamp('2011-01-01 08:00:00'),
#  Timestamp('2011-01-01 09:00:00'),
#  Timestamp('2011-01-01 10:00:00'),
#  Timestamp('2011-01-01 11:00:00'),
#  Timestamp('2011-01-01 12:00:00'),
#  Timestamp('2011-01-01 13:00:00'),
#  Timestamp('2011-01-01 14:00:00'),
#  Timestamp('2011-01-01 15:00:00'),
#  Timestamp('2011-01-01 16:00:00'),
#  Timestamp('2011-01-01 17:00:00'),
#  Timestamp('2011-01-01 18:00:00'),
#  Timestamp('2011-01-01 19:00:00'),
#  Timestamp('2011-01-01 20:00:00'),
#  Timestamp('2011-01-01 21:00:00'),
#  Timestamp('2011-01-01 22:00:00'),
#  Timestamp('2011-01-01 23:00:00'),
#  Timestamp('2011-02-01 00:00:00'),
#  Timestamp('2011-02-01 01:00:00'),
#  Timestamp('2011-02-01 02:00:00'),
# ...

# %%
np.random.shuffle(l)

# %%
dfTrain = dfTrain.loc[l]

# %%
dfTrain.head()
# Out:
#                         count  season  holiday  workingday  weather   temp  \
# datetime
# 2011-01-11 18:00:00  6.133398       4        0           1        1  17.22
# 2011-12-06 17:00:00  5.533389       2        0           0        3  27.88
# 2011-09-16 20:00:00  5.420535       3        0           1        2  20.50
# 2011-08-18 14:00:00  5.209486       3        0           1        1  33.62
# 2012-09-04 06:00:00  4.718499       2        0           1        1  17.22
#
#                      atemp  humidity  windspeed  year  month  day  dayofweek  \
# datetime
# 2011-01-11 18:00:00  21.21        58     7.0015  2011      1   11          1
# 2011-12-06 17:00:00  31.82        83    19.0012  2011     12    6          1
# 2011-09-16 20:00:00  24.24        55     0.0000  2011      9   16          4
# 2011-08-18 14:00:00  37.88        46    22.0028  2011      8   18          3
# 2012-09-04 06:00:00  21.21        26    15.0013  2012      9    4          1
#
#                      hour
# ...

# %%
dfTrain.shape
# Out:
# (10886, 14)

# %%
dfTrain.shape[0]
# Out:
# 10886

# %%
trainno=int(0.75* dfTrain.shape[0])

# %%
trainno
# Out:
# 8164

# %%
testno=dfTrain.shape[0]-trainno

# %%
testno
# Out:
# 2722

# %%
dfTrain.columns
# Out:
# Index(['count', 'season', 'holiday', 'workingday', 'weather', 'temp', 'atemp',
#        'humidity', 'windspeed', 'year', 'month', 'day', 'dayofweek', 'hour'],
#       dtype='object')

# %%
dfTrain.iloc[:trainno].to_csv('LRTrain.csv',index=False,header=False)

# %%
dfTrain.iloc[trainno:].to_csv('LRTest.csv',index=False,header=False)

# %%
dfTest=dfTrain.iloc[trainno:]

# %% [markdown]
# # Predict dataset

# %%
columnsRequired
# Out:
# ['count',
#  'season',
#  'holiday',
#  'workingday',
#  'weather',
#  'temp',
#  'atemp',
#  'humidity',
#  'windspeed']

# %%
dfVal = pd.read_csv('test.csv', parse_dates=['datetime'],index_col=0)
dfVal.head()
# Out:
#                      season  holiday  workingday  weather   temp   atemp  \
# datetime
# 2011-01-20 00:00:00       1        0           1        1  10.66  11.365
# 2011-01-20 01:00:00       1        0           1        1  10.66  13.635
# 2011-01-20 02:00:00       1        0           1        1  10.66  13.635
# 2011-01-20 03:00:00       1        0           1        1  10.66  12.880
# 2011-01-20 04:00:00       1        0           1        1  10.66  12.880
#
#                      humidity  windspeed
# datetime
# 2011-01-20 00:00:00        56    26.0027
# 2011-01-20 01:00:00        56     0.0000
# 2011-01-20 02:00:00        56     0.0000
# 2011-01-20 03:00:00        56    11.0014
# 2011-01-20 04:00:00        56    11.0014

# %%
dfVal['year'] = dfVal.index.year
dfVal['month'] = dfVal.index.month
dfVal['day'] = dfVal.index.day
dfVal['dayofweek'] = dfVal.index.dayofweek
dfVal['hour'] = dfVal.index.hour

# %%
dfVal.to_csv('LRVal.csv',index=True,index_label='datetime')

# %%
dfVal.head()
# Out:
#                      season  holiday  workingday  weather   temp   atemp  \
# datetime
# 2011-01-20 00:00:00       1        0           1        1  10.66  11.365
# 2011-01-20 01:00:00       1        0           1        1  10.66  13.635
# 2011-01-20 02:00:00       1        0           1        1  10.66  13.635
# 2011-01-20 03:00:00       1        0           1        1  10.66  12.880
# 2011-01-20 04:00:00       1        0           1        1  10.66  12.880
#
#                      humidity  windspeed  year  month  day  dayofweek  hour
# datetime
# 2011-01-20 00:00:00        56    26.0027  2011      1   20          3     0
# 2011-01-20 01:00:00        56     0.0000  2011      1   20          3     1
# 2011-01-20 02:00:00        56     0.0000  2011      1   20          3     2
# 2011-01-20 03:00:00        56    11.0014  2011      1   20          3     3
# 2011-01-20 04:00:00        56    11.0014  2011      1   20          3     4

# %% [markdown]
# # Train On Sagemaker using Linera Regression

# %%
import boto3
import re

# %% [markdown]
# To train the Model four steps needs to be followed
# 1. Data should be present in S3
# 2. Mention S3 bucket name from where you need to upload the data
# 3. Mention the Instance type on which Model needs to be trained
# 4. Mention S3 location wherein output prediction needs to be stores

# %% [markdown]
# ### Step 1:Upload the data from Local to AWS S3

# %%
bucketNM = 'ec2-east-sagemaker-demo'

TrainFile = r'LR/LRTrain.csv'
TestFile = r'LR/LRTest.csv'
Valfile = r'LR/LRVal.csv'
ModelFolder=r'LR/model/'

# %%
s3ModelOutput= r's3://{0}/{1}'.format(bucketNM,ModelFolder)
s3Train = r's3://{0}/{1}'.format(bucketNM,TrainFile)
s3Test = r's3://{0}/{1}'.format(bucketNM,TestFile)
s3Val = r's3://{0}/{1}'.format(bucketNM,Valfile)

# %%
s3Train
# Out:
# 's3://ec2-east-sagemaker-demo/LR/LRTrain.csv'

# %%
with open('LRTrain.csv','rb') as f:
    boto3.Session().resource('s3').Bucket(bucketNM).Object(TrainFile).upload_fileobj(f)

# %%
with open('LRTest.csv','rb') as f:
    boto3.Session().resource('s3').Bucket(bucketNM).Object(TestFile).upload_fileobj(f)

# %%
with open('LRVal.csv','rb') as f:
    boto3.Session().resource('s3').Bucket(bucketNM).Object(Valfile).upload_fileobj(f)

# %% [markdown]
# ### Download Built in Sagemaker Algorithm in sagemaker instance

# %%
import sagemaker
from sagemaker import get_execution_role

# %%
sagemakerSess=sagemaker.Session()

# %%
role=get_execution_role()

# %%
role
# Out:
# 'arn:aws:iam::177300670946:role/service-role/AmazonSageMaker-ExecutionRole-20200718T120127'

# %% [markdown]
# https://docs.aws.amazon.com/sagemaker/latest/dg/sagemaker-algo-docker-registry-paths.html

# %% [markdown]
# linear-learner

# %%
sagemakerSess.boto_region_name
# Out:
# 'us-east-1'

# %%
ECRdockercontainer=sagemaker.amazon.amazon_estimator.get_image_uri(sagemakerSess.boto_region_name,'linear-learner','latest')
# Out:
# 'get_image_uri' method will be deprecated in favor of 'ImageURIProvider' class in SageMaker Python SDK v2.

# %%
ECRdockercontainer
# Out:
# '382416733822.dkr.ecr.us-east-1.amazonaws.com/linear-learner:latest'

# %%
instance_type='ml.m4.xlarge'#'local'
#

# %% [markdown]
# ### Build Model

# %%
LRModel=sagemaker.estimator.Estimator(image_name=ECRdockercontainer,
                                      role=role,
                                      train_instance_count=1,
                                        train_instance_type=instance_type,
                                        output_path=s3ModelOutput,
                                        sagemaker_session=sagemakerSess,
                                        base_job_name ='LR-Demo-v1'
                                        )
# Out:
# WARNING:root:Parameter image_name will be renamed to image_uri in SageMaker Python SDK v2.

# %%
len(dfTrain.columns)
# Out:
# 14

# %%
LRModel.set_hyperparameters(feature_dim='auto',
                           predictor_type='regressor',
                           normalize_data=False,
                           epochs=1

                           )

# %%
#LRModel.set_hyperparameters()

# %%
LRModel.hyperparameters()
# Out:
# {'feature_dim': 'auto',
#  'predictor_type': 'regressor',
#  'normalize_data': False,
#  'mini_batch_size': 8164}

# %% [markdown]
# ### Training DATA and Test Data location

# %%
trainConfig=sagemaker.session.s3_input(s3_data=s3Train,content_type='text/csv')
# Out:
# WARNING:sagemaker:'s3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.

# %%
trainConfig

# %%
testConfig=sagemaker.session.s3_input(s3_data=s3Test,content_type='text/csv')
# Out:
# WARNING:sagemaker:'s3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.

# %% [markdown]
# # Train Model

# %%
LRModel.fit({'train': trainConfig,'validation':testConfig})
# Out:
# 2020-07-26 17:11:14 Starting - Starting the training job...
# 2020-07-26 17:11:16 Starting - Launching requested ML instances.........
# 2020-07-26 17:12:56 Starting - Preparing the instances for training......
# 2020-07-26 17:13:51 Downloading - Downloading input data...
# 2020-07-26 17:14:43 Training - Training image download completed. Training in progress..Docker entrypoint called with argument(s): train
# Running default environment configuration script
# ...

# %%
# Deploy Model

# %%
predictmodel=LRModel.deploy(initial_instance_count=1,instance_type='ml.m4.xlarge',endpoint_name='LR-Demo-v1')
# Out:
# WARNING:sagemaker:Parameter image will be renamed to image_uri in SageMaker Python SDK v2.
# ---------------!

# %%
from sagemaker.predictor import csv_serializer, json_deserializer

# %%
predictmodel.content_type = 'text/csv'
predictmodel.serializer = csv_serializer
predictmodel.deserializer = None

# %%
dfTest.columns
# Out:
# Index(['count', 'season', 'holiday', 'workingday', 'weather', 'temp', 'atemp',
#        'humidity', 'windspeed', 'year', 'month', 'day', 'dayofweek', 'hour'],
#       dtype='object')

# %%
dfTest.head(10)
# Out:
#                         count  season  holiday  workingday  weather   temp  \
# datetime
# 2012-06-02 06:00:00  4.290459       1        0           1        1   6.56
# 2012-07-07 11:00:00  5.908083       3        0           0        1  38.54
# 2012-09-14 16:00:00  6.335054       3        0           1        2  29.52
# 2012-04-09 06:00:00  5.153292       3        0           1        2  27.88
# 2011-12-12 17:00:00  5.886104       4        0           1        2  12.30
# 2011-06-08 21:00:00  4.744932       3        0           0        2  28.70
# 2011-09-18 20:00:00  5.198497       3        0           0        2  22.14
# 2011-04-02 10:00:00  3.951244       1        0           1        2   8.20
# 2011-01-02 18:00:00  5.129899       1        0           1        2   9.84
# 2011-11-07 15:00:00  4.990433       3        0           1        1  35.26
#
#                       atemp  humidity  windspeed  year  month  day  dayofweek  \
# datetime
# ...

# %%
dfVal.columns
# Out:
# Index(['season', 'holiday', 'workingday', 'weather', 'temp', 'atemp',
#        'humidity', 'windspeed', 'year', 'month', 'day', 'dayofweek', 'hour'],
#       dtype='object')

# %%
k=dfTest.iloc[:10,1:]

# %%
k
# Out:
#                      season  holiday  workingday  weather   temp   atemp  \
# datetime
# 2012-06-02 06:00:00       1        0           1        1   6.56   9.090
# 2012-07-07 11:00:00       3        0           0        1  38.54  43.940
# 2012-09-14 16:00:00       3        0           1        2  29.52  33.335
# 2012-04-09 06:00:00       3        0           1        2  27.88  31.820
# 2011-12-12 17:00:00       4        0           1        2  12.30  16.665
# 2011-06-08 21:00:00       3        0           0        2  28.70  33.335
# 2011-09-18 20:00:00       3        0           0        2  22.14  25.760
# 2011-04-02 10:00:00       1        0           1        2   8.20  10.605
# 2011-01-02 18:00:00       1        0           1        2   9.84  12.880
# 2011-11-07 15:00:00       3        0           1        1  35.26  42.425
#
#                      humidity  windspeed  year  month  day  dayofweek  hour
# datetime
# ...

# %%
k = np.array(k).astype('float32')

# %%
k
# Out:
# array([[1.00000e+00, 0.00000e+00, 1.00000e+00, 1.00000e+00, 6.56000e+00,
#         9.09000e+00, 8.60000e+01, 7.00150e+00, 2.01200e+03, 6.00000e+00,
#         2.00000e+00, 5.00000e+00, 6.00000e+00],
#        [3.00000e+00, 0.00000e+00, 0.00000e+00, 1.00000e+00, 3.85400e+01,
#         4.39400e+01, 3.80000e+01, 1.29980e+01, 2.01200e+03, 7.00000e+00,
#         7.00000e+00, 5.00000e+00, 1.10000e+01],
#        [3.00000e+00, 0.00000e+00, 1.00000e+00, 2.00000e+00, 2.95200e+01,
#         3.33350e+01, 5.10000e+01, 0.00000e+00, 2.01200e+03, 9.00000e+00,
#         1.40000e+01, 4.00000e+00, 1.60000e+01],
#        [3.00000e+00, 0.00000e+00, 1.00000e+00, 2.00000e+00, 2.78800e+01,
#         3.18200e+01, 8.90000e+01, 7.00150e+00, 2.01200e+03, 4.00000e+00,
#         9.00000e+00, 0.00000e+00, 6.00000e+00],
#        [4.00000e+00, 0.00000e+00, 1.00000e+00, 2.00000e+00, 1.23000e+01,
#         1.66650e+01, 5.60000e+01, 0.00000e+00, 2.01100e+03, 1.20000e+01,
#         1.20000e+01, 0.00000e+00, 1.70000e+01],
# ...

# %%
predictmodel.predict(k)
# Out:
# b'{"predictions": [{"score": 2.9820556640625}, {"score": 5.902740478515625}, {"score": 5.84063720703125}, {"score": 4.28253173828125}, {"score": 4.97021484375}, {"score": 5.386627197265625}, {"score": 5.450531005859375}, {"score": 3.6617431640625}, {"score": 3.91595458984375}, {"score": 5.6021728515625}]}'

# %%
# Host Model in production

# %%
endpoint_name='LR-Demo-v1'
predictor = sagemaker.predictor.RealTimePredictor(endpoint=endpoint_name)

# %%
from sagemaker.predictor import csv_serializer, json_deserializer

predictor.content_type = 'text/csv'
predictor.serializer = csv_serializer
predictor.deserializer = None

# %%
df_all = dfVal

# %%
df_all.head()
# Out:
#                      season  holiday  workingday  weather   temp   atemp  \
# datetime
# 2011-01-20 00:00:00       1        0           1        1  10.66  11.365
# 2011-01-20 01:00:00       1        0           1        1  10.66  13.635
# 2011-01-20 02:00:00       1        0           1        1  10.66  13.635
# 2011-01-20 03:00:00       1        0           1        1  10.66  12.880
# 2011-01-20 04:00:00       1        0           1        1  10.66  12.880
#
#                      humidity  windspeed  year  month  day  dayofweek  hour
# datetime
# 2011-01-20 00:00:00        56    26.0027  2011      1   20          3     0
# 2011-01-20 01:00:00        56     0.0000  2011      1   20          3     1
# 2011-01-20 02:00:00        56     0.0000  2011      1   20          3     2
# 2011-01-20 03:00:00        56    11.0014  2011      1   20          3     3
# 2011-01-20 04:00:00        56    11.0014  2011      1   20          3     4

# %%
df_all.columns[1:]
# Out:
# Index(['holiday', 'workingday', 'weather', 'temp', 'atemp', 'humidity',
#        'windspeed', 'year', 'month', 'day', 'dayofweek', 'hour'],
#       dtype='object')

# %%
arr_test = df_all.values

# %%
predictions = []
for arr in np.array_split(arr_test,5):
    result = predictor.predict(arr)
    result = result.decode("utf-8")
    result = result.split(',')
    print(result[0])
# Out:
# {"predictions": [{"score": 2.85003662109375}
# {"predictions": [{"score": 3.885986328125}
# {"predictions": [{"score": 5.412261962890625}
# {"predictions": [{"score": 3.7330322265625}
# {"predictions": [{"score": 4.5462646484375}
